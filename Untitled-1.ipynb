# %%
// This is a scratchpad to test the logic before applying changes.
// I will simulate the getUserPosts logic.

const sortBy = "likes"; // or "latest", "comments", "bookmarks"

let query = supabaseAdmin.from("posts").select("*").eq("user_id", userId);

if (sortBy === "latest") {
  query = query.order("created_at", { ascending: false });
} else if (sortBy === "likes") {
  query = query.order("likes_count", { ascending: false });
} else if (sortBy === "comments") {
  query = query.order("comments_count", { ascending: false });
} else if (sortBy === "bookmarks") {
  // This is tricky. Posts don't have "bookmarks_count" usually.
  // I need to check schema.ts to see if posts have bookmarks_count.
}

# %%
// This is a placeholder since I cannot edit the file directly with this tool.
// I will use replace_string_in_file.
